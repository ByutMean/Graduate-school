# %%
import numpy as np
import pandas as pd
data=pd.read_csv(r'C:\Users\BM\Downloads\age.csv',encoding='cp949',index_col=0)
data=data.div(data['총인구수'],axis=0)
del data['총인구수'],data['연령구간인구수']

# %%
data
# Out:
#                                     0세        1세        2세        3세  \
# 행정구역
# 서울특별시  (1100000000)           0.006214  0.007155  0.007540  0.007353
# 서울특별시 종로구 (1111000000)        0.004213  0.005130  0.005886  0.005783
# 서울특별시 종로구 청운효자동(1111051500)   0.006103  0.006178  0.006781  0.007911
# 서울특별시 종로구 사직동(1111053000)     0.004555  0.006673  0.007944  0.007203
# 서울특별시 종로구 삼청동(1111054000)     0.004128  0.001376  0.007568  0.004472
# ...                                ...       ...       ...       ...
# 제주특별자치도 서귀포시 서홍동(5013058000)  0.008561  0.010443  0.012325  0.009973
# 제주특별자치도 서귀포시 대륜동(5013059000)  0.010904  0.011054  0.011577  0.011875
# 제주특별자치도 서귀포시 대천동(5013060000)  0.013392  0.016393  0.013777  0.013546
# 제주특별자치도 서귀포시 중문동(5013061000)  0.005241  0.008330  0.007675  0.009266
# 제주특별자치도 서귀포시 예래동(5013062000)  0.003565  0.006366  0.006366  0.006366
#
#                                     4세        5세        6세        7세  \
# 행정구역
# ...

# %%
dong=str(input('동 이름을 입력하세요 :'))
# Out:
# 동 이름을 입력하세요 :공릉2

# %%
aa=data.index.str.contains(dong)
data2=data[aa]

# %%
data2
# Out:
#                                   0세        1세        2세        3세        4세  \
# 행정구역
# 서울특별시 노원구 공릉2동(1135060000)  0.006267  0.007882  0.008822  0.008605  0.007809
#
#                                   5세       6세        7세        8세        9세  \
# 행정구역
# 서울특별시 노원구 공릉2동(1135060000)  0.009713  0.00899  0.009786  0.009521  0.010629
#
#                             ...      91세       92세       93세       94세  \
# 행정구역                        ...
# 서울특별시 노원구 공릉2동(1135060000)  ...  0.00053  0.000434  0.000169  0.000337
#
#                                  95세       96세       97세       98세       99세  \
# 행정구역
# 서울특별시 노원구 공릉2동(1135060000)  0.000217  0.000145  0.000096  0.000072  0.000024
#
#                              100세 이상
# 행정구역
# 서울특별시 노원구 공릉2동(1135060000)  0.000241
#
# [1 rows x 101 columns]

# %%
import matplotlib.pyplot as plt
plt.rc('font',family='Malgun Gothic')
data2.T.plot()
plt.show()

# %%
data.loc[np.power(data.sub(data2.iloc[0],axis=1),2).sum(axis=1).sort_values().index[:5]].T.plot()
# Out:
# <AxesSubplot:>
